# %% [markdown]
# For the following examples we'll use `seaborn` titanic dataset

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")
df["signup_date"] = pd.date_range(start="1912-04-01", periods=len(df)).astype(str)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone signup_date
# 0      man        True  NaN  Southampton    no  False  1912-04-01
# 1    woman       False    C    Cherbourg   yes  False  1912-04-02
# 2    woman       False  NaN  Southampton   yes   True  1912-04-03
# 3    woman       False    C  Southampton   yes  False  1912-04-04
# 4      man        True  NaN  Southampton    no   True  1912-04-05
# ..     ...         ...  ...          ...   ...    ...         ...
# 886    man        True  NaN  Southampton    no   True  1914-09-04
# 887  woman       False    B  Southampton   yes   True  1914-09-05
# 888  woman       False  NaN  Southampton    no  False  1914-09-06
# 889    man        True    C    Cherbourg   yes   True  1914-09-07
# 890    man        True  NaN   Queenstown    no   True  1914-09-08
#
# [891 rows x 16 columns]

# %% [markdown]
# ## handle_data
#
# helper function for data handling, including features such as formatting columns, handling NaN values

# %%
from ml_qol import handle_data

df = handle_data(df, date_col="signup_date")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone signup_date
# 0      man        True  Nan  Southampton    no  False  1912-04-01
# 1    woman       False    C    Cherbourg   yes  False  1912-04-02
# 2    woman       False  Nan  Southampton   yes   True  1912-04-03
# 3    woman       False    C  Southampton   yes  False  1912-04-04
# 4      man        True  Nan  Southampton    no   True  1912-04-05
# ..     ...         ...  ...          ...   ...    ...         ...
# 886    man        True  Nan  Southampton    no   True  1914-09-04
# 887  woman       False    B  Southampton   yes   True  1914-09-05
# 888  woman       False  Nan  Southampton    no  False  1914-09-06
# 889    man        True    C    Cherbourg   yes   True  1914-09-07
# 890    man        True  Nan   Queenstown    no   True  1914-09-08
#
# [891 rows x 16 columns]

# %% [markdown]
# #### `handle_data` parameters
#
# - **df**: Dataset as pd.DataFrame
# - **date_col**: name of date column to convert with pd.to_datetime()
# - **log_cols**: list of column names to transform with np.log1p. Useful for reducing skewed distributions

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## expand_date
#
# use date column to add features such as year, month, day, week of year etc

# %%
from ml_qol import expand_date

fe_df = expand_date(df, date_col="signup_date")
fe_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  embark_town alive  alone signup_date  year month  day  \
# 0      man  ...  Southampton    no  False  1912-04-01  1912     4    1
# 1    woman  ...    Cherbourg   yes  False  1912-04-02  1912     4    2
# 2    woman  ...  Southampton   yes   True  1912-04-03  1912     4    3
# 3    woman  ...  Southampton   yes  False  1912-04-04  1912     4    4
# 4      man  ...  Southampton    no   True  1912-04-05  1912     4    5
# ..     ...  ...          ...   ...    ...         ...   ...   ...  ...
# 886    man  ...  Southampton    no   True  1914-09-04  1914     9    4
# 887  woman  ...  Southampton   yes   True  1914-09-05  1914     9    5
# 888  woman  ...  Southampton    no  False  1914-09-06  1914     9    6
# 889    man  ...    Cherbourg   yes   True  1914-09-07  1914     9    7
# 890    man  ...   Queenstown    no   True  1914-09-08  1914     9    8
#
#      weekday  is_weekend  week_of_year
# 0          0       False            14
# 1          1       False            14
# 2          2       False            14
# 3          3       False            14
# 4          4       False            14
# ..       ...         ...           ...
# 886        4       False            36
# 887        5        True            36
# 888        6        True            36
# 889        0       False            37
# 890        1       False            37
#
# [891 rows x 22 columns]

# %% [markdown]
# #### `expand_date` parameters
#
# - **df**: Dataset as pd.DataFrame
# - **date_col**: name of date column used to create additional features

# %% [markdown]
# ## combine_features
#
# create new features by combining numerical and categorical columns, such as creating products, ratios, concatenating columns together etc.

# %%
from ml_qol import combine_features

fe_df = combine_features(
    fe_df,
    target_col="survived",
    num_features=["fare", "age"],
    cat_features=["sex", "class"],
)
fe_df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# 0         3    male  22.0      1      0   7.2500        S   Third    man
# 1         1  female  38.0      1      0  71.2833        C   First  woman
# 2         3  female  26.0      0      0   7.9250        S   Third  woman
# 3         1  female  35.0      1      0  53.1000        S   First  woman
# 4         3    male  35.0      0      0   8.0500        S   Third    man
# ..      ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886       2    male  27.0      0      0  13.0000        S  Second    man
# 887       1  female  19.0      0      0  30.0000        S   First  woman
# 888       3  female   NaN      1      2  23.4500        S   Third  woman
# 889       1    male  26.0      0      0  30.0000        C   First    man
# 890       3    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male  ...  year month day  weekday is_weekend  week_of_year  \
# 0          True  ...  1912     4   1        0      False            14
# 1         False  ...  1912     4   2        1      False            14
# 2         False  ...  1912     4   3        2      False            14
# 3         False  ...  1912     4   4        3      False            14
# 4          True  ...  1912     4   5        4      False            14
# ..          ...  ...   ...   ...  ..      ...        ...           ...
# 886        True  ...  1914     9   4        4      False            36
# 887       False  ...  1914     9   5        5       True            36
# 888       False  ...  1914     9   6        6       True            36
# 889        True  ...  1914     9   7        0      False            37
# 890        True  ...  1914     9   8        1      False            37
#
#      fare_times_age  fare_div_age     sex_class  survived
# 0          159.5000      0.329545    male_Third         0
# 1         2708.7654      1.875876  female_First         1
# 2          206.0500      0.304808  female_Third         1
# 3         1858.5000      1.517143  female_First         1
# 4          281.7500      0.230000    male_Third         0
# ..              ...           ...           ...       ...
# 886        351.0000      0.481481   male_Second         0
# 887        570.0000      1.578947  female_First         1
# 888             NaN           NaN  female_Third         0
# 889        780.0000      1.153846    male_First         1
# 890        248.0000      0.242188    male_Third         0
#
# [891 rows x 25 columns]

# %% [markdown]
# #### `combine_features` parameters
#
# - **df**: Dataset as pd.DataFrame
# - **target_col**: name of target column. Passing this ensures it is dropped and does not cause target leakage when creating new features
# - **num_features**: list of numerical columns to create new features based on. Creates products and ratios for each combination. Defaults to all numerical columns, (this may lead to high memory usage and bad performance)
# - **cat_features**: list of categorical columns to create new features based on. Creates new features by concatenating two categorical columns together. Defaults to all categorical columns, (this may lead to high memory usage and bad performance)
# - **safety_check**: Ensures length of num_features/cat_features does not exceed 50, since it may cause high memory usage and bad performance. Defaults to True. Pass safety_check=False to allow larger computations

# %% [markdown]
# ## target_encode
#
# Target encodes based on list of columns provided. This performs a kfold split to ensure no data leakage occurs. If a column is numerical, it will bin the column first, then perform target encoding
#
# Currently only supports regression tasks, hence we'll use `fare` as target column

# %%
from ml_qol import target_encode, target_encode_test
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.2)

te_df = target_encode(train_df, target_col="fare", cols=["age", "class", "sex"])
te_df
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           1       3    male   4.0      1      1   11.1333        S   Third
# 1           1       1  female   NaN      1      0   52.0000        S   First
# 2           1       1  female   NaN      1      0   82.1708        C   First
# 3           1       3  female  31.0      1      1   20.5250        S   Third
# 4           1       3  female  36.0      1      0   17.4000        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 707         1       1  female  15.0      0      1  211.3375        S   First
# 708         0       2    male  39.0      0      0   13.0000        S  Second
# 709         0       3    male   NaN      8      2   69.5500        S   Third
# 710         0       2  female  26.0      1      1   26.0000        S  Second
# 711         0       2    male  54.0      0      0   26.0000        S  Second
#
#        who  ...  age_te_max age_te_min class_te_mean class_te_median  \
# 0    child  ...     81.8583    16.7000     13.623466          8.0500
# 1    woman  ...         NaN        NaN     88.085948         64.2896
# 2    woman  ...         NaN        NaN     88.085948         64.2896
# 3    woman  ...    164.8667     7.8542     13.623466          8.0500
# 4    woman  ...    512.3292     0.0000     13.623466          8.0500
# ..     ...  ...         ...        ...           ...             ...
# 707  child  ...     14.4542     7.2250     82.867631         59.6792
# 708    man  ...     83.1583     0.0000     21.111916         14.5000
# 709    man  ...         NaN        NaN     13.531998          8.0500
# 710  woman  ...     56.4958     7.7750     21.111916         14.5000
# 711    man  ...     78.2667    14.0000     21.111916         14.5000
#
#      class_te_max class_te_min  sex_te_mean  sex_te_median  sex_te_max  \
# 0         69.5500          0.0    25.890816       10.87085    512.3292
# 1        512.3292          0.0    44.913330       20.25000    512.3292
# 2        512.3292          0.0    44.913330       20.25000    512.3292
# 3         69.5500          0.0    44.913330       20.25000    512.3292
# 4         69.5500          0.0    44.913330       20.25000    512.3292
# ..            ...          ...          ...            ...         ...
# 707      512.3292          0.0    43.330219       21.03750    263.0000
# 708       73.5000          0.0    24.770707       10.50000    512.3292
# 709       69.5500          0.0    24.770707       10.50000    512.3292
# 710       73.5000          0.0    43.330219       21.03750    263.0000
# 711       73.5000          0.0    24.770707       10.50000    512.3292
#
#      sex_te_min
# 0          0.00
# 1          6.75
# 2          6.75
# 3          6.75
# 4          6.75
# ..          ...
# 707        6.75
# 708        0.00
# 709        0.00
# 710        6.75
# 711        0.00
#
# [712 rows x 28 columns]

# %% [markdown]
# `target_encode_test` can be used to target encode the test set based on the training set

# %%
X_test = test_df.drop(columns="fare")

te_test_df = target_encode_test(
    train_df, X_test, target_col="fare", cols=["age", "class", "sex"]
)
te_test_df
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked   class    who  \
# 0           1       2  female   2.0      1      1        S  Second  child
# 1           0       3    male  30.0      0      0        C   Third    man
# 2           0       2    male  27.0      0      0        S  Second    man
# 3           0       3    male  26.0      1      0        C   Third    man
# 4           0       1    male  31.0      1      0        S   First    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 174         0       3  female  41.0      0      5        S   Third  woman
# 175         1       1  female  30.0      0      0        S   First  woman
# 176         1       2  female  28.0      1      0        S  Second  woman
# 177         0       3    male  38.0      0      0        S   Third    man
# 178         1       3  female   NaN      0      0        Q   Third  woman
#
#      adult_male  ... age_te_max age_te_min class_te_mean  class_te_median  \
# 0         False  ...    39.6875    12.2875     21.197184          14.5000
# 1          True  ...    93.5000     7.2250     13.898384           8.0500
# 2          True  ...   211.5000     6.9750     21.197184          14.5000
# 3          True  ...    56.4958     7.7750     13.898384           8.0500
# 4          True  ...   164.8667     7.7500     85.431348          57.9792
# ..          ...  ...        ...        ...           ...              ...
# 174       False  ...   134.5000     7.1250     13.898384           8.0500
# 175       False  ...    93.5000     7.2250     85.431348          57.9792
# 176       False  ...    82.1708     7.7958     21.197184          14.5000
# 177        True  ...   153.4625     7.8958     13.898384           8.0500
# 178       False  ...        NaN        NaN     13.898384           8.0500
#
#     class_te_max  class_te_min  sex_te_mean  sex_te_median  sex_te_max  \
# 0        73.5000           0.0    44.550734        21.0750    512.3292
# 1        69.5500           0.0    26.233683        11.1875    512.3292
# 2        73.5000           0.0    26.233683        11.1875    512.3292
# 3        69.5500           0.0    26.233683        11.1875    512.3292
# 4       512.3292           0.0    26.233683        11.1875    512.3292
# ..           ...           ...          ...            ...         ...
# 174      69.5500           0.0    44.550734        21.0750    512.3292
# 175     512.3292           0.0    44.550734        21.0750    512.3292
# 176      73.5000           0.0    44.550734        21.0750    512.3292
# 177      69.5500           0.0    26.233683        11.1875    512.3292
# 178      69.5500           0.0    44.550734        21.0750    512.3292
#
#      sex_te_min
# 0          6.75
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# ..          ...
# 174        6.75
# 175        6.75
# 176        6.75
# 177        0.00
# 178        6.75
#
# [179 rows x 27 columns]
